# %%
# %matplotlib inline
import random
import matplotlib.pyplot as plt

# 画出温度变化图
# 创建一个figure
plt.figure(figsize = (20, 8), dpi=100)

# 准备x，y轴数据
x = range(60)
y_shanghai = [random.uniform(15, 18) for i in x]

# 画折线图
plt.plot(x, y_shanghai, label='上海')
plt.show()

# %%
# %matplotlib inline
import random
import matplotlib.pyplot as plt


# 画出温度变化图
# 创建一个figure
plt.figure(figsize = (20, 8), dpi=100)

# 准备x，y轴数据
x = range(60)
y_shanghai = [random.uniform(15, 18) for i in x]

# 增加下面两行到代码
x_ch = ["11点{}分".format(i) for i in x]
y_ticks = range(40)

# 修改x,y坐标的刻度
plt.xticks(x[::5], x_ch[::5])
plt.yticks(y_ticks[::5])

# 画折线图
plt.plot(x, y_shanghai, label='上海')
plt.show()
# Out:
# /home/jhonchen/.virtualenvs/ai/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 28857 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/jhonchen/.virtualenvs/ai/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 20998 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/jhonchen/.virtualenvs/ai/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 28857 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/jhonchen/.virtualenvs/ai/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 20998 missing from current font.
#   font.set_text(s, 0, flags=flags)
